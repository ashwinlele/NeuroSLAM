# %%
run main.py
# Out:
# The name of the dataset is D:\Python_workspace\Klaus_short_retake10.avi
# The data set is successfully opened
# The value of PC_VT_INJECT_ENERGY is 1
# The value of PC_DIM_XY is 7
# The vaule of PC_DIM_TH is 1
# The value of PC_W_E&I_DIM is 5
# The vaule of EXP_DELTA_PC_THRESHOLD is 1.5
# The value of VT_MATCH_THRESHOLD is 21
# The value of FOV_DEG is 66.0
# The value of VTRANS_SCALE is 100
# The quantization on img is 8
# The simulation is started at 11/19/19 15:45:38
# over_vtrans 80.625
# max_offset 2
# The counter is 1
# The maximum pc value is 0.494
# The counter is 2
# The maximum pc value is 0.6500000000000001
# The counter is 3
# The maximum pc value is 0.71
# The counter is 4
# The maximum pc value is 0.746
# -----------------------------------------------------------
# The current number of the iteration is 50
# 1.41900014877 seconds are elapsed per 100 frames.
# The number of units of the VT is 25
# The number of units of the experience map is 25
# 11/19/19 15:45:39
# ...

# %%
IMAGE_VT_Y_RANGE        = slice((480/2 - 80 - 40), (480/2 + 80 - 40))
IMAGE_VT_X_RANGE        = slice((640/2 - 280 + 15), (640/2 + 280 + 15))
IMAGE_VTRANS_Y_RANGE    = slice(270, 430)
IMAGE_VROT_Y_RANGE      = slice(80, 240)
IMAGE_ODO_X_RANGE       = slice(180+15, 460+15)
print IMAGE_VT_Y_RANGE, IMAGE_VT_X_RANGE,   IMAGE_VTRANS_Y_RANGE, IMAGE_VROT_Y_RANGE, IMAGE_ODO_X_RANGE
# Out:
# slice(120, 280, None) slice(55, 615, None) slice(270, 430, None) slice(80, 240, None) slice(195, 475, None)

# %%
vrot_acc = np.pi/180 * 0
th_pc = 5
if (vrot_acc - th_pc * (np.pi/4) > np.pi):
    vrot_acc = 0.7 * vrot_acc + 0.3 * (th_pc * (np.pi/4) + 2*np.pi)
    print 'angle'
    print (th_pc * (np.pi/4) + 2*np.pi) * 180/np.pi
elif (vrot_acc - th_pc * (np.pi/4) < -np.pi):
    vrot_acc = 0.7 * vrot_acc + 0.3 * (th_pc * (np.pi/4) - 2*np.pi)        
    print 'angle2'
    print (th_pc * (np.pi/4)- 2*np.pi) * 180/np.pi
else:
    vrot_acc = 0.7 * vrot_acc + 0.3 * th_pc * (np.pi/2)
    print 'normal'
    
    
print np.round(((np.pi/2)+np.pi/4.001)/(np.pi/2))


print IMAGE_VT_Y_RANGE
print 160*2**4

np.round(-0.501)

offset =1
cwl = 4       
e = (cwl-offset)
A=np.array([1,2,3,4])
B=np.array([8,6,4,2])
print (A[offset:cwl] - B[:e])
print (A[:e] - B[offset:cwl])

print (1.000/POSECELL_VTRANS_SCALING)/16.000
# Out:
# angle2
# -135.0
# 1.0
# slice(120, 280, None)
# 2560
# [-6 -3  0]
# [-5 -2  1]
# 0.625

# %%
range(9,10)
# Out:
# [9]

# %%
        img_pc = mpimg.imread(r'D:\Python_workspace\ratslam-Klaus_XY55_2d_v2_quant2_Forum\MATLAB\Posecell_colormap\Posecell_colormap'+str(loop/100)+'.png')
        plot.imshow(img_pc)
